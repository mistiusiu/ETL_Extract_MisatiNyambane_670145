# %% [markdown]
# # ETL Load

# %% [markdown]
# ## Load Setup

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# ### Connecting to SQLite

# %%
# Creating the connections
full_conn = sqlite3.connect("loaded_data/full_data.db")
incremental_conn = sqlite3.connect("loaded_data/incremental_data.db")

# %% [markdown]
# ### Importing Files

# %% [markdown]
# Loading the transformed CSV files as Pandas dataframes.

# %%
# Loading the transformed files
df_full = pd.read_csv("transformed_full.csv")
df_incremental = pd.read_csv("transformed_incremental.csv")

# %% [markdown]
# Observing the data inside the transformed CSV files

# %%
# Displaying the full and incremental transformed dataframes
df_full.head()
# Out:
#     Age Primary streaming service  Hours per day While working  \
# 0  18.0                   Spotify            3.0           Yes
# 1  63.0                   Pandora            1.5           Yes
# 2  18.0                   Spotify            4.0            No
# 3  61.0             YouTube Music            2.5           Yes
# 4  18.0                   Spotify            4.0           Yes
#
#   Instrumentalist Composer         Fav genre Exploratory Foreign languages  \
# 0             Yes      Yes             Latin         Yes               Yes
# 1              No       No              Rock         Yes                No
# 2              No       No  Video game music          No               Yes
# 3              No      Yes              Jazz         Yes               Yes
# 4              No       No               R&B         Yes                No
#
#      BPM  ... Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 0  156.0  ...                    Sometimes     3.0        0.0      1.0  0.0
# 1  119.0  ...                       Rarely     7.0        2.0      2.0  1.0
# 2  132.0  ...              Very frequently     7.0        7.0     10.0  2.0
# 3   84.0  ...                        Never     9.0        7.0      3.0  3.0
# 4  107.0  ...                       Rarely     7.0        2.0      5.0  9.0
#
#   Music effects Anxiety_label Depression_label Insomnia_label OCD_label
# 0       Improve          Mild          Minimal        Minimal   Minimal
# 1       Improve        Severe          Minimal        Minimal   Minimal
# 2     No effect        Severe           Severe       Critical   Minimal
# 3       Improve      Critical           Severe           Mild      Mild
# 4       Improve        Severe          Minimal       Moderate  Critical
#
# [5 rows x 35 columns]

# %%
df_incremental.head()
# Out:
#     Age          Primary streaming service  Hours per day While working  \
# 0  18.0                            Spotify            4.0           Yes
# 1  17.0  I do not use a streaming service.            1.0           Yes
# 2  36.0                            Spotify            1.0            No
# 3  24.0                            Spotify            3.0           Yes
# 4  18.0                            Spotify            5.0           Yes
#
#   Instrumentalist Composer  Fav genre Exploratory Foreign languages    BPM  \
# 0              No       No      Metal         Yes               Yes   77.0
# 1             Yes      Yes       Folk          No                No  118.0
# 2             Yes      Yes  Classical          No                No  132.0
# 3              No       No       Rock         Yes               Yes  115.0
# 4              No      Yes      Metal         Yes               Yes  157.0
#
#    ... Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 0  ...              Very frequently     1.0        0.0      8.0  2.0
# 1  ...                    Sometimes     7.0        3.0      1.0  5.0
# 2  ...                        Never     8.0        9.0      3.0  0.0
# 3  ...                    Sometimes     9.0        6.0      4.0  3.0
# 4  ...                        Never     7.0        9.0      5.0  0.0
#
#   Music effects Anxiety_label Depression_label Insomnia_label OCD_label
# 0     No effect       Minimal          Minimal         Severe   Minimal
# 1       Improve        Severe             Mild        Minimal  Moderate
# 2     No effect        Severe         Critical           Mild   Minimal
# 3       Improve      Critical         Moderate           Mild      Mild
# 4       Improve        Severe         Critical       Moderate   Minimal
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Loading to SQLite Database

# %% [markdown]
# ### Load Full Transformed Data

# %%
df_full.to_sql("full_data", con=full_conn, if_exists="replace", index=False)
# Out:
# 736

# %% [markdown]
# ### Load Incremental Transformed Data

# %%
df_incremental.to_sql("incremental_data", con=incremental_conn, if_exists="replace", index=False)
# Out:
# 692

# %% [markdown]
# ## Verification

# %%
# Previewing the data using SQL Queries
df_full_loaded = pd.read_sql_query("SELECT * FROM full_data LIMIT 5", full_conn)
df_full_loaded
# Out:
#     Age Primary streaming service  Hours per day While working  \
# 0  18.0                   Spotify            3.0           Yes
# 1  63.0                   Pandora            1.5           Yes
# 2  18.0                   Spotify            4.0            No
# 3  61.0             YouTube Music            2.5           Yes
# 4  18.0                   Spotify            4.0           Yes
#
#   Instrumentalist Composer         Fav genre Exploratory Foreign languages  \
# 0             Yes      Yes             Latin         Yes               Yes
# 1              No       No              Rock         Yes                No
# 2              No       No  Video game music          No               Yes
# 3              No      Yes              Jazz         Yes               Yes
# 4              No       No               R&B         Yes                No
#
#      BPM  ... Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 0  156.0  ...                    Sometimes     3.0        0.0      1.0  0.0
# 1  119.0  ...                       Rarely     7.0        2.0      2.0  1.0
# 2  132.0  ...              Very frequently     7.0        7.0     10.0  2.0
# 3   84.0  ...                        Never     9.0        7.0      3.0  3.0
# 4  107.0  ...                       Rarely     7.0        2.0      5.0  9.0
#
#   Music effects Anxiety_label Depression_label Insomnia_label OCD_label
# 0       Improve          Mild          Minimal        Minimal   Minimal
# 1       Improve        Severe          Minimal        Minimal   Minimal
# 2     No effect        Severe           Severe       Critical   Minimal
# 3       Improve      Critical           Severe           Mild      Mild
# 4       Improve        Severe          Minimal       Moderate  Critical
#
# [5 rows x 35 columns]

# %%
df_incremental_loaded = pd.read_sql_query("SELECT * FROM incremental_data LIMIT 5", incremental_conn)
df_incremental_loaded
# Out:
#     Age          Primary streaming service  Hours per day While working  \
# 0  18.0                            Spotify            4.0           Yes
# 1  17.0  I do not use a streaming service.            1.0           Yes
# 2  36.0                            Spotify            1.0            No
# 3  24.0                            Spotify            3.0           Yes
# 4  18.0                            Spotify            5.0           Yes
#
#   Instrumentalist Composer  Fav genre Exploratory Foreign languages    BPM  \
# 0              No       No      Metal         Yes               Yes   77.0
# 1             Yes      Yes       Folk          No                No  118.0
# 2             Yes      Yes  Classical          No                No  132.0
# 3              No       No       Rock         Yes               Yes  115.0
# 4              No      Yes      Metal         Yes               Yes  157.0
#
#    ... Frequency [Video game music] Anxiety Depression Insomnia  OCD  \
# 0  ...              Very frequently     1.0        0.0      8.0  2.0
# 1  ...                    Sometimes     7.0        3.0      1.0  5.0
# 2  ...                        Never     8.0        9.0      3.0  0.0
# 3  ...                    Sometimes     9.0        6.0      4.0  3.0
# 4  ...                        Never     7.0        9.0      5.0  0.0
#
#   Music effects Anxiety_label Depression_label Insomnia_label OCD_label
# 0     No effect       Minimal          Minimal         Severe   Minimal
# 1       Improve        Severe             Mild        Minimal  Moderate
# 2     No effect        Severe         Critical           Mild   Minimal
# 3       Improve      Critical         Moderate           Mild      Mild
# 4       Improve        Severe         Critical       Moderate   Minimal
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Closing the Database Connections

# %%
# Closing connections
full_conn.close()
incremental_conn.close()
